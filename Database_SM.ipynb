-- %% [markdown]
-- # [System_Information]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [System_Information]    Script Date: 6/24/2024 2:31:09 PM ******/
CREATE DATABASE [System_Information]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'System_Information', FILENAME = N'D:\Program Files\MSSQL16.SQLEXPRESS\MSSQL\DATA\System_Information.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'System_Information_log', FILENAME = N'D:\Program Files\MSSQL16.SQLEXPRESS\MSSQL\DATA\System_Information_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [System_Information] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [System_Information].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [System_Information] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [System_Information] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [System_Information] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [System_Information] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [System_Information] SET ARITHABORT OFF 
GO
ALTER DATABASE [System_Information] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [System_Information] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [System_Information] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [System_Information] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [System_Information] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [System_Information] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [System_Information] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [System_Information] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [System_Information] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [System_Information] SET  DISABLE_BROKER 
GO
ALTER DATABASE [System_Information] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [System_Information] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [System_Information] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [System_Information] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [System_Information] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [System_Information] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [System_Information] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [System_Information] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [System_Information] SET  MULTI_USER 
GO
ALTER DATABASE [System_Information] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [System_Information] SET DB_CHAINING OFF 
GO
ALTER DATABASE [System_Information] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [System_Information] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [System_Information] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [System_Information] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [System_Information] SET QUERY_STORE = ON
GO
ALTER DATABASE [System_Information] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Performance]

-- %%
USE [System_Information]
GO

-- %%
/****** Object:  Table [dbo].[Performance]    Script Date: 6/24/2024 2:31:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Performance](
	[Time] [datetime] NULL,
	[cpu_usage] [numeric](5, 2) NULL,
	[memory_usage] [numeric](5, 2) NULL,
	[cpu_interrupts] [numeric](18, 0) NULL,
	[cpu_calls] [numeric](18, 0) NULL,
	[memory_used] [numeric](18, 0) NULL,
	[memory_free] [numeric](18, 0) NULL,
	[byte_sent] [numeric](18, 0) NULL,
	[byte_received] [numeric](18, 0) NULL,
	[disk_usage] [numeric](5, 2) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [System_Information]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [System_Information] SET  READ_WRITE 
GO
